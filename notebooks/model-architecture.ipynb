# %% [markdown]
# # VisualBacter
#
# Detección de ETA's mediante vision computacional con redes neuronales convolucionales
#
# Escrito por:
#
# Juan Diego y George Giosue

# %% [markdown]
# ## Setup data

# %%
import zipfile

data_path = '/content/data.zip'
lib_path= '/content/lib.zip'

extract_data_path = '/content/data'
extract_lib_path = '/content/lib'


with zipfile.ZipFile(data_path, 'r') as zip_ref:
    zip_ref.extractall(extract_data_path)

print("Unzipped file in:", extract_data_path)

# Descomprimir el archivo zip
with zipfile.ZipFile(lib_path, 'r') as zip_ref:
    zip_ref.extractall(extract_lib_path)

print("Unzipped file in:", extract_lib_path)
# Out:
# Unzipped file in: /content/data
# Unzipped file in: /content/lib

# %% [markdown]
# # Imports

# %%
import csv
import sys
import tensorflow as tf
import cv2
import numpy as np
import os
import sys
from pathlib import Path
import matplotlib.pyplot as plt
import string
from keras import Model
from keras.models import Sequential
from keras.layers import Layer
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, Input, BatchNormalization, Permute, LSTM, Reshape, Concatenate, Lambda, Add
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from os import scandir
from time import time

if '/content/lib' not in sys.path:
    sys.path.append('/content/lib')
import lib.utils as fns

tf.__version__
# Out:
# '2.15.0'

# %% [markdown]
# # GPU

# %%
from tensorflow.python.client import device_lib

print(device_lib.list_local_devices(), "\n\n", "Num GPUs Available: ",len(tf.config.list_physical_devices('GPU')))
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11202981591603332603
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 14626652160
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 405808078810119373
# physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"
# xla_global_id: 416903419
# ]
#
#  Num GPUs Available:  1

# %% [markdown]
# ### Avoid OOM errors by setting GPU Memory Consumption Growth

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Data preparation

# %%
TRAIN_DATA_PATH = "/content/data/data/train"
TEST_DATA_PATH = "/content/data/data/test"
VALID_DATA_PATH = "/content/data/data/valid"

TRAIN_CLASSES = {
  "filename" : "_classes.csv",
  "fields" : [],
  "rows" : []
}

TEST_CLASSES = {
  "filename" : "_classes.csv",
  "fields" : [],
  "rows" : []
}

VALID_CLASSES = {
  "filename" : "_classes.csv",
  "fields" : [],
  "rows" : []
}

train_data = []
test_data = []
valid_data = []

with open(TRAIN_DATA_PATH+"/"+TRAIN_CLASSES['filename'], 'r') as csvfile:
    csvreader = csv.reader(csvfile)

    columns = next(csvreader)

    for column in columns:
      TRAIN_CLASSES['fields'].append(column.strip())

    for row in csvreader:
        TRAIN_CLASSES['rows'].append(row)


with open(TEST_DATA_PATH+"/"+TEST_CLASSES['filename'], 'r') as csvfile:
    csvreader = csv.reader(csvfile)

    columns = next(csvreader)

    for column in columns:
      TEST_CLASSES['fields'].append(column.strip())

    for row in csvreader:
        TEST_CLASSES['rows'].append(row)

with open(VALID_DATA_PATH+"/"+VALID_CLASSES['filename'], 'r') as csvfile:
    csvreader = csv.reader(csvfile)

    columns = next(csvreader)

    for column in columns:
      VALID_CLASSES['fields'].append(column.strip())

    for row in csvreader:
        VALID_CLASSES['rows'].append(row)

def compose_images_with_class(payload, image_name, data_frame):
  target_row = []

  for row in data_frame["rows"]:
    if row[0] == image_name:
      target_row = row



  features = data_frame["fields"][1::]
  predictions = [int(p) for p in target_row[1::]]

  index_p = 0
  prediction = ''

  for index, p in enumerate(predictions):
    if p == 1:
      index_p = index

  prediction = features[index_p]


  return {
    "image": payload,
    "image_name": image_name,
    "classname": prediction
  }

CLASS_NAMES = ['Campylobacter', 'E.Coli', 'Staphylococcus', 'Streptococcus', 'Yeast']

train_data = fns.imgs_to_array(TRAIN_DATA_PATH,'_classes.csv',cv2.IMREAD_GRAYSCALE, lambda payload, image_name: compose_images_with_class(payload, image_name, TRAIN_CLASSES))

test_data = fns.imgs_to_array(TEST_DATA_PATH, '_classes.csv', cv2.IMREAD_GRAYSCALE, lambda payload, image_name: compose_images_with_class(payload, image_name, TEST_CLASSES))

valid_data = fns.imgs_to_array(VALID_DATA_PATH, '_classes.csv', cv2.IMREAD_GRAYSCALE, lambda payload, image_name: compose_images_with_class(payload, image_name, VALID_CLASSES))

print(f"""
      SIZE OF TRAIN DATA: {len(train_data)}
      SIZE OF TEST DATA: {len(test_data)}
      SIZE OF VALID DATA: {len(valid_data)}
      """)
# Out:
#       SIZE OF TRAIN DATA: 390
#       SIZE OF TEST DATA: 26
#       SIZE OF VALID DATA: 41

# %% [markdown]
# ## Show Preview of Train Data

# %%
preview_train_data_index = 100

plt.figure()
plt.imshow(train_data[preview_train_data_index]['image'])
plt.colorbar()
plt.xlabel(train_data[preview_train_data_index]['classname'])
plt.grid(False)
plt.show()

# %% [markdown]
# ## Show Preview of Test Data

# %%
preview_test_data_index = 10

plt.figure()
plt.imshow(test_data[preview_test_data_index]['image'])
plt.colorbar()
plt.xlabel(test_data[preview_test_data_index]['classname'])
plt.grid(False)
plt.show()

# %% [markdown]
# # Hyperparameters

# %%
IMG_SHAPE = (150, 150)
INPUT_SHAPE = IMG_SHAPE + (1,)
KERNEL_SIZE = (3, 3)
conv_activation = 'relu'
activation = 'softmax'
MODEL_PARAMETERS = {
    'losses': tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    'optimizer': 'adam',
    'metrics': ['accuracy'],
    'callbacks': [
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)
    ]
}

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Architecture

# %%
model = Sequential()

model.add(Conv2D(32, KERNEL_SIZE, activation=conv_activation, input_shape=INPUT_SHAPE))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, KERNEL_SIZE, activation=conv_activation))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, KERNEL_SIZE, activation=conv_activation))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, KERNEL_SIZE, activation=conv_activation))
model.add(MaxPooling2D((2, 2)))

model.add(Flatten())

model.add(Dense(512, activation=conv_activation))
model.add(Dropout(0.5))

model.add(Dense(len(CLASS_NAMES), activation = activation))

# %% [markdown]
# ## Summary

# %%
from tensorflow import keras

model.summary()
keras.utils.plot_model(model, 'model_arch.png', show_shapes=True)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 148, 148, 32)      320
#
#  max_pooling2d_17 (MaxPooli  (None, 74, 74, 32)        0
#  ng2D)
#
#  conv2d_18 (Conv2D)          (None, 72, 72, 64)        18496
#
#  max_pooling2d_18 (MaxPooli  (None, 36, 36, 64)        0
#  ng2D)
#
#  conv2d_19 (Conv2D)          (None, 34, 34, 128)       73856
#
#  max_pooling2d_19 (MaxPooli  (None, 17, 17, 128)       0
#  ng2D)
#
#  conv2d_20 (Conv2D)          (None, 15, 15, 128)       147584
#
#  max_pooling2d_20 (MaxPooli  (None, 7, 7, 128)         0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_8 (Dense)             (None, 512)               3211776
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_9 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 3454597 (13.18 MB)
# Trainable params: 3454597 (13.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Compile and Train Model

# %%
model.compile(optimizer='adam',
              loss=MODEL_PARAMETERS['losses'],
              metrics=MODEL_PARAMETERS['metrics'],
              run_eagerly=True)

# %%
def resize_grayscale_image(image_array, target_size=(150, 150)):
    image_tensor = tf.expand_dims(tf.convert_to_tensor(image_array, dtype=tf.float32), axis=0)
    image_tensor = tf.expand_dims(image_tensor, axis=-1)

    resized_image = tf.image.resize(image_tensor, target_size)

    resized_image_array = tf.squeeze(resized_image).numpy()

    return resized_image_array

# %%
train_labels = [CLASS_NAMES.index(dc['classname']) for dc in train_data]
test_labels = [CLASS_NAMES.index(dc['classname']) for dc in test_data]

train_images = np.array([ resize_grayscale_image(dc['image']) for dc in train_data])
test_images = np.array([ resize_grayscale_image(dc['image']) for dc in test_data])

# %%
train_labels = np.array(train_labels)
test_labels = np.array(test_labels)

# %%
history = model.fit(
    train_images,
    train_labels,
    epochs=80,
    validation_data=(test_images, test_labels),
    batch_size=26,
    callbacks=MODEL_PARAMETERS['callbacks'])
# Out:
# Epoch 1/80
# 15/15 [==============================] - 3s 50ms/step - loss: 13.0673 - accuracy: 0.4128 - val_loss: 1.3582 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 2/80
# 15/15 [==============================] - 1s 45ms/step - loss: 1.4369 - accuracy: 0.5205 - val_loss: 1.4366 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 3/80
# 15/15 [==============================] - 1s 47ms/step - loss: 1.1842 - accuracy: 0.6026 - val_loss: 1.2405 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 4/80
# 15/15 [==============================] - 1s 47ms/step - loss: 1.0191 - accuracy: 0.6205 - val_loss: 0.9771 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 5/80
# 15/15 [==============================] - 1s 44ms/step - loss: 0.9053 - accuracy: 0.6590 - val_loss: 1.0687 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 6/80
# 15/15 [==============================] - 1s 46ms/step - loss: 1.0622 - accuracy: 0.5949 - val_loss: 0.9569 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 7/80
# 15/15 [==============================] - 1s 47ms/step - loss: 0.9107 - accuracy: 0.6769 - val_loss: 1.1029 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 8/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.9806 - accuracy: 0.6410 - val_loss: 1.2410 - val_accuracy: 0.3462 - lr: 0.0010
# Epoch 9/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.9109 - accuracy: 0.6513 - val_loss: 0.8798 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 10/80
# 15/15 [==============================] - 1s 47ms/step - loss: 0.7614 - accuracy: 0.7077 - val_loss: 0.7941 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 11/80
# 15/15 [==============================] - 1s 44ms/step - loss: 0.7830 - accuracy: 0.7179 - val_loss: 0.9165 - val_accuracy: 0.7308 - lr: 0.0010
# Epoch 12/80
# 15/15 [==============================] - 1s 46ms/step - loss: 0.7991 - accuracy: 0.7128 - val_loss: 1.1799 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 13/80
# 15/15 [==============================] - 1s 46ms/step - loss: 0.7448 - accuracy: 0.7231 - val_loss: 0.8407 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 14/80
# 15/15 [==============================] - 1s 56ms/step - loss: 0.8137 - accuracy: 0.6974 - val_loss: 1.1090 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 15/80
# 15/15 [==============================] - 1s 58ms/step - loss: 0.7512 - accuracy: 0.7231 - val_loss: 0.7542 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 16/80
# 15/15 [==============================] - 1s 62ms/step - loss: 0.8938 - accuracy: 0.7051 - val_loss: 3.3817 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 17/80
# 15/15 [==============================] - 1s 47ms/step - loss: 1.1971 - accuracy: 0.6641 - val_loss: 0.9888 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 18/80
# 15/15 [==============================] - 1s 47ms/step - loss: 0.7777 - accuracy: 0.7538 - val_loss: 0.7058 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 19/80
# 15/15 [==============================] - 1s 44ms/step - loss: 0.5978 - accuracy: 0.7923 - val_loss: 1.0259 - val_accuracy: 0.6923 - lr: 0.0010
# Epoch 20/80
# 15/15 [==============================] - 1s 44ms/step - loss: 0.7496 - accuracy: 0.7462 - val_loss: 0.8446 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 21/80
# 15/15 [==============================] - 1s 47ms/step - loss: 0.7945 - accuracy: 0.7179 - val_loss: 0.8771 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 22/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.6871 - accuracy: 0.8000 - val_loss: 0.6734 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 23/80
# 15/15 [==============================] - 1s 48ms/step - loss: 0.8790 - accuracy: 0.7205 - val_loss: 1.0493 - val_accuracy: 0.7308 - lr: 0.0010
# Epoch 24/80
# 15/15 [==============================] - 1s 44ms/step - loss: 1.2260 - accuracy: 0.7154 - val_loss: 1.3280 - val_accuracy: 0.4231 - lr: 0.0010
# Epoch 25/80
# 15/15 [==============================] - 1s 44ms/step - loss: 1.0591 - accuracy: 0.6462 - val_loss: 1.0361 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 26/80
# 15/15 [==============================] - 1s 44ms/step - loss: 1.0102 - accuracy: 0.6974 - val_loss: 1.4840 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 27/80
# 15/15 [==============================] - 1s 44ms/step - loss: 1.1677 - accuracy: 0.6077 - val_loss: 1.1649 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 28/80
# 15/15 [==============================] - 1s 58ms/step - loss: 0.9197 - accuracy: 0.6846 - val_loss: 0.9734 - val_accuracy: 0.6538 - lr: 2.0000e-04
# Epoch 29/80
# 15/15 [==============================] - 1s 58ms/step - loss: 0.8282 - accuracy: 0.7103 - val_loss: 0.8563 - val_accuracy: 0.6923 - lr: 2.0000e-04
# Epoch 30/80
# 15/15 [==============================] - 1s 60ms/step - loss: 0.7015 - accuracy: 0.7769 - val_loss: 0.7601 - val_accuracy: 0.7308 - lr: 2.0000e-04
# Epoch 31/80
# 15/15 [==============================] - 1s 68ms/step - loss: 0.6196 - accuracy: 0.7923 - val_loss: 0.6526 - val_accuracy: 0.7308 - lr: 2.0000e-04
# Epoch 32/80
# 15/15 [==============================] - 1s 57ms/step - loss: 0.5759 - accuracy: 0.7974 - val_loss: 0.6338 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 33/80
# 15/15 [==============================] - 1s 63ms/step - loss: 0.6295 - accuracy: 0.7667 - val_loss: 0.7229 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 34/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.5561 - accuracy: 0.8179 - val_loss: 0.6272 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 35/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.5253 - accuracy: 0.8179 - val_loss: 0.5869 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 36/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.5090 - accuracy: 0.8385 - val_loss: 0.5174 - val_accuracy: 0.7308 - lr: 2.0000e-04
# Epoch 37/80
# 15/15 [==============================] - 1s 44ms/step - loss: 0.5105 - accuracy: 0.8154 - val_loss: 0.5552 - val_accuracy: 0.7308 - lr: 2.0000e-04
# Epoch 38/80
# 15/15 [==============================] - 1s 43ms/step - loss: 0.4556 - accuracy: 0.8590 - val_loss: 0.5232 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 39/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.4357 - accuracy: 0.8564 - val_loss: 0.5109 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 40/80
# 15/15 [==============================] - 1s 46ms/step - loss: 0.4368 - accuracy: 0.8538 - val_loss: 0.4865 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 41/80
# 15/15 [==============================] - 1s 48ms/step - loss: 0.4152 - accuracy: 0.8718 - val_loss: 0.4802 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 42/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.3992 - accuracy: 0.8692 - val_loss: 0.4716 - val_accuracy: 0.8077 - lr: 2.0000e-04
# Epoch 43/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.3929 - accuracy: 0.8846 - val_loss: 0.5534 - val_accuracy: 0.8462 - lr: 2.0000e-04
# Epoch 44/80
# 15/15 [==============================] - 1s 44ms/step - loss: 0.4375 - accuracy: 0.8487 - val_loss: 0.5333 - val_accuracy: 0.8077 - lr: 2.0000e-04
# Epoch 45/80
# 15/15 [==============================] - 1s 44ms/step - loss: 0.4027 - accuracy: 0.8692 - val_loss: 0.6155 - val_accuracy: 0.7308 - lr: 2.0000e-04
# Epoch 46/80
# 15/15 [==============================] - 1s 46ms/step - loss: 0.3817 - accuracy: 0.8667 - val_loss: 0.4956 - val_accuracy: 0.7692 - lr: 2.0000e-04
# Epoch 47/80
# 15/15 [==============================] - 1s 45ms/step - loss: 0.3789 - accuracy: 0.8846 - val_loss: 0.5130 - val_accuracy: 0.8077 - lr: 2.0000e-04
# Epoch 48/80
# 15/15 [==============================] - 1s 54ms/step - loss: 0.3574 - accuracy: 0.8872 - val_loss: 0.4871 - val_accuracy: 0.8077 - lr: 1.0000e-04
# Epoch 49/80
# 15/15 [==============================] - 1s 59ms/step - loss: 0.3569 - accuracy: 0.8949 - val_loss: 0.5025 - val_accuracy: 0.8077 - lr: 1.0000e-04
# Epoch 50/80
# 15/15 [==============================] - 1s 64ms/step - loss: 0.3299 - accuracy: 0.8872 - val_loss: 0.5216 - val_accuracy: 0.8077 - lr: 1.0000e-04
# Epoch 51/80
# 15/15 [==============================] - 1s 51ms/step - loss: 0.3120 - accuracy: 0.9000 - val_loss: 0.5178 - val_accuracy: 0.7692 - lr: 1.0000e-04
# Epoch 52/80
# 15/15 [==============================] - 1s 47ms/step - loss: 0.3339 - accuracy: 0.9051 - val_loss: 0.5261 - val_accuracy: 0.7692 - lr: 1.0000e-04

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print(f'{test_acc*100}%')
# Out:
# 1/1 - 0s - loss: 0.4716 - accuracy: 0.8077 - 40ms/epoch - 40ms/step
# 80.7692289352417%

# %% [markdown]
# # Performance

# %%
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['accuracy'], color='teal', label='accuracy')
plt.plot(history.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Prediccion

# %%
preview_valid_data_index = 10

plt.figure()
plt.imshow(valid_data[preview_valid_data_index]['image'])
plt.colorbar()
plt.xlabel(valid_data[preview_valid_data_index]['classname'])
plt.grid(False)
plt.show()

# %%
valid_images = np.array([ resize_grayscale_image(dc['image']) for dc in valid_data])

valid_image_test = valid_images[preview_valid_data_index]

# %%
valid_image_test.shape
# Out:
# (150, 150)

# %%
if valid_image_test.ndim == 2:
    valid_image_test = np.expand_dims(valid_image_test, axis=-1)

valid_image_test = np.expand_dims(valid_image_test, axis=0)

# %%
valid_image_test.shape
# Out:
# (1, 150, 150, 1)

# %%
# predict

predictions = model.predict(valid_image_test)

index_max = np.argmax(predictions[0])
index_min = np.argmin(predictions[0])

print(f"""
    The prediction is [MAX ARG]: {CLASS_NAMES[index_max]}
""")
# Out:
# 1/1 [==============================] - 0s 251ms/step
#
#     The prediction is [MAX ARG]: Streptococcus

# %%
plt.figure(figsize=(10, 6))
plt.bar(CLASS_NAMES, predictions[0], color='blue')
plt.xlabel('Bacteria')
plt.ylabel('Probability')
plt.title('Model Predictions for Each Class of Bacteria')
plt.ylim(0, 1.1)
plt.xticks(rotation=45)

plt.show()

# %%
MODELS_PATH = os.path.join(Path(os.getcwd()), 'saved_model')

MODEL_NAME = "visualbacter"

VERSION = '1'

model.save(os.path.join(MODELS_PATH, MODEL_NAME, VERSION))

# %% [markdown]
# # TF Lite

# %%
model_loaded =tf.keras.models.load_model(os.path.join(MODELS_PATH, MODEL_NAME))


converter = tf.lite.TFLiteConverter.from_keras_model(model_loaded)

tflite_model = converter.convert()


with open(f'{os.path.join(MODELS_PATH, MODEL_NAME, VERSION)}/save_model_edge.tflite', 'wb') as f:
    f.write(tflite_model)
